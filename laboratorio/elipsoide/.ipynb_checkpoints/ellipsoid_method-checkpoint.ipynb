% %%
ellipsoid_example
% Out:
% p =
%
% inputParser object with properties:
%
%    CaseSensitive   : false
%    FunctionName    : false
%    KeepUnmatched   : false
%    PartialMatching : false
%    StructExpand    : true
%
% Defined parameters:
%
%    {}
%
%
% ...
% = Metodo Elipsoidal =
% ...
% i	 D(t+11)						 a				 x[i] = [ x[1], x[2]]		 Valor objetivo
% ...
%  1  	 D = [  22 , -11.11111 ; -11.11111 , 22.22222 ]	 a = [ 1.17851 , 1.17851 ]	 x[i] = [ 0.00000 , 0.00000 ]	 -> Valor objetivo = 0.0000000000
%  2  	 D = [  29 , -17.63668 ; -17.63668 , 18.34215 ]	 a = [ 0.88155 , -0.00932 ]	 x[i] = [ 0.00000 , 0.00000 ]	 -> Valor objetivo = 0.0000000000
%  3  	 D = [  23 , -7.83853 ; -7.83853 , 8.15207 ]	 a = [ -0.49113 , 1.41827 ]	 x[i] = [ 0.00000 , 0.00000 ]	 -> Valor objetivo = 0.0000000000
%  4  	 D = [  10 , -3.48379 ; -3.48379 , 8.54451 ]	 a = [ 1.12447 , 0.87919 ]	 x[i] = [ 0.00000 , 0.00000 ]	 -> Valor objetivo = 0.0000000000
% ...
